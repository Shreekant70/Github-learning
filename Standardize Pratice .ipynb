# %%
import numpy as np 
import pandas as pd
import seaborn as sns

# %%
a = np.random.randn(1000)
a
# Out:
# array([ 5.21028072e-01,  1.05468917e+00, -1.12939400e+00,  1.10731558e-02,
#        -1.30180622e+00, -8.65812094e-01, -5.80029905e-01,  2.18295773e+00,
#         4.66104373e-01,  8.29805747e-01,  7.77308794e-01, -2.40459826e-01,
#        -2.00915678e-01,  1.71393834e-01, -3.72198022e-02, -3.99625084e-01,
#        -2.83468040e-01,  1.23896077e+00,  1.08827544e+00, -5.16337603e-01,
#         8.82629574e-01, -3.73761576e-01,  1.24431020e-01, -1.72334465e+00,
#         2.02808991e-01,  4.63790174e-01,  4.66280898e-01, -5.66408474e-01,
#        -3.46539092e-01, -1.12815753e+00, -1.29842442e+00,  2.28307553e-01,
#        -1.58910786e+00,  2.44726697e-01,  8.22328139e-01,  1.88338252e+00,
#        -5.47080398e-01, -5.84540929e-01,  3.20114313e-01, -8.11356986e-01,
#         2.50914427e-01,  7.94573534e-02,  1.45674277e-01,  2.05200254e+00,
#        -6.14487365e-01, -3.20579428e-01, -5.39237749e-01,  1.00120239e+00,
# ...

# %%
sns.displot(a)

# %%
sns.kdeplot(a)
# Out:
# <Axes: ylabel='Density'>
